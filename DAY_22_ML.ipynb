# %%
import pandas as pd

# %%
pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (1.14.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (2.2.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (2.12.5)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (6.0.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (3.1.6)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (2.1.5)
# Requirement already satisfied: visions==0.7.4 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (2.1.1)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (2.32.5)
# Requirement already satisfied: tqdm>=4.48.2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (4.67.3)
# Requirement already satisfied: seaborn>=0.10.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas-profiling) (2.0.2)
# Requirement already satisfied: attrs>=19.3.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.6.1)
# Requirement already satisfied: imagehash in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.2)
# Requirement already satisfied: Pillow in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.4.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.24.0->pandas-profiling) (2026.2.25)
# Requirement already satisfied: colorama in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: PyWavelets in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv(r"C:\Rahul KM Ghosh_PGD202564310\100_daysML\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
pip install ydata-profiling
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (1.14.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (2.2.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic<3,>=2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (2.12.5)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (3.1.6)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (2.1.1)
# Collecting minify-html>=0.15.0 (from ydata-profiling)
#   Downloading minify_html-0.18.1-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (4.67.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling)
#   Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting typeguard<5,>=4 (from ydata-profiling)
#   Downloading typeguard-4.5.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: imagehash==4.3.2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from ydata-profiling) (4.3.2)
# Collecting wordcloud>=1.9.4 (from ydata-profiling)
#   Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<0.63,>=0.60 (from ydata-profiling)
#   Downloading numba-0.62.1-cp312-cp312-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: PyWavelets in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imagehash==4.3.2->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba<0.63,>=0.60->ydata-profiling)
#   Downloading llvmlite-0.45.1-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2024.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.2.25)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: colorama in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling)
#   Downloading puremagic-2.1.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.16.0)
# Downloading ydata_profiling-4.18.1-py2.py3-none-any.whl (400 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.62.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 31.4 MB/s  0:00:00
# Downloading llvmlite-0.45.1-cp312-cp312-win_amd64.whl (38.1 MB)
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#    -------------------- ------------------- 19.9/38.1 MB 89.8 MB/s eta 0:00:01
#    -------------------- ------------------- 19.9/38.1 MB 89.8 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/38.1 MB 44.9 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/38.1 MB 44.9 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/38.1 MB 44.9 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/38.1 MB 44.9 MB/s eta 0:00:01
#    ------------------------- -------------- 24.1/38.1 MB 44.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.0/38.1 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.1/38.1 MB 21.1 MB/s  0:00:01
# Downloading statsmodels-0.14.6-cp312-cp312-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 9.5/9.5 MB 74.3 MB/s  0:00:00
# Downloading typeguard-4.5.1-py3-none-any.whl (36 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading minify_html-0.18.1-cp312-cp312-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 3.1/3.1 MB 60.8 MB/s  0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading wordcloud-1.9.6-cp312-cp312-win_amd64.whl (307 kB)
# Downloading puremagic-2.1.0-py3-none-any.whl (67 kB)
# Installing collected packages: minify-html, filetype, typeguard, puremagic, patsy, multimethod, llvmlite, dacite, numba, wordcloud, visions, statsmodels, ydata-profiling
#
#    --- ------------------------------------  1/13 [filetype]
#    ------ ---------------------------------  2/13 [typeguard]
#    --------- ------------------------------  3/13 [puremagic]
#    ------------ ---------------------------  4/13 [patsy]
#    ------------ ---------------------------  4/13 [patsy]
#   Attempting uninstall: multimethod
#    ------------ ---------------------------  4/13 [patsy]
#     Found existing installation: multimethod 2.0.2
#    ------------ ---------------------------  4/13 [patsy]
#    --------------- ------------------------  5/13 [multimethod]
#     Uninstalling multimethod-2.0.2:
#    --------------- ------------------------  5/13 [multimethod]
#       Successfully uninstalled multimethod-2.0.2
#    --------------- ------------------------  5/13 [multimethod]
#   Attempting uninstall: llvmlite
#    --------------- ------------------------  5/13 [multimethod]
#     Found existing installation: llvmlite 0.46.0
#    --------------- ------------------------  5/13 [multimethod]
#     Uninstalling llvmlite-0.46.0:
#    --------------- ------------------------  5/13 [multimethod]
#       Successfully uninstalled llvmlite-0.46.0
#    --------------- ------------------------  5/13 [multimethod]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------ ---------------------  6/13 [llvmlite]
#   Attempting uninstall: numba
#    ------------------ ---------------------  6/13 [llvmlite]
#     Found existing installation: numba 0.64.0
#    ------------------ ---------------------  6/13 [llvmlite]
#    ------------------------ ---------------  8/13 [numba]
#     Uninstalling numba-0.64.0:
#    ------------------------ ---------------  8/13 [numba]
#       Successfully uninstalled numba-0.64.0
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    ------------------------ ---------------  8/13 [numba]
#    --------------------------- ------------  9/13 [wordcloud]
#   Attempting uninstall: visions
#    --------------------------- ------------  9/13 [wordcloud]
#     Found existing installation: visions 0.7.4
#    --------------------------- ------------  9/13 [wordcloud]
#     Uninstalling visions-0.7.4:
#    --------------------------- ------------  9/13 [wordcloud]
#       Successfully uninstalled visions-0.7.4
#    --------------------------- ------------  9/13 [wordcloud]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    ------------------------------ --------- 10/13 [visions]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    --------------------------------- ------ 11/13 [statsmodels]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ------------------------------------ --- 12/13 [ydata-profiling]
#    ---------------------------------------- 13/13 [ydata-profiling]
#
# Successfully installed dacite-1.9.2 filetype-1.2.0 llvmlite-0.45.1 minify-html-0.18.1 multimethod-1.12 numba-0.62.1 patsy-1.0.2 puremagic-2.1.0 statsmodels-0.14.6 typeguard-4.5.1 visions-0.8.1 wordcloud-1.9.6 ydata-profiling-4.18.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script filetype.exe is installed in 'c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script puremagic.exe is installed in 'c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages\~lvmlite.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages\~lvmlite'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages\~umba'.
#   You can safely remove it manually.
#   WARNING: The script wordcloud_cli.exe is installed in 'c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pandas_profiling.exe and ydata_profiling.exe are installed in 'c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.

# %%
# Out:
#   Cell In[18], line 1
#     pip install ydata-profiling
#         ^
# SyntaxError: invalid syntax

# %%
# Out:
#   Cell In[19], line 1
#     python -m venv myenv
#               ^
# SyntaxError: invalid syntax

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df)
profile.to_file("output.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(df)
#       4 profile.to_file("output.html")
#
# File c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:11
#       9 with warnings.catch_warnings():
#      10     warnings.simplefilter("ignore")
# ---> 11     import pkg_resources
#      13 if not is_pyspark_installed():
#      14     from typing import TypeVar
#
# ModuleNotFoundError: No module named 'pkg_resources'
