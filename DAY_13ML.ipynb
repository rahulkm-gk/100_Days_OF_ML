# %%
import pandas as pd
import numpy as np

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("somya2115/placement-csv")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Tech Lab 1\.cache\kagglehub\datasets\somya2115\placement-csv\versions\1

# %%
new_df = pd.read_csv(r"C:\Rahul KM Ghosh_PGD202564310\100_daysML\archive\placement.csv")

# %%
new_df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
new_df.sample()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 86          86   5.1  128.0          0

# %%
new_df.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
new_df.columns
# Out:
# Index(['Unnamed: 0', 'cgpa', 'iq', 'placement'], dtype='object')

# %%
new_df.drop(columns="Unnamed: 0",inplace=True)

# %%
new_df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
plt.scatter(new_df["cgpa"], new_df["iq"],c=new_df["placement"])
plt.show()

# %%
x = new_df[["cgpa","iq"]]
y = new_df["placement"]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,Y_test = train_test_split(x,y,test_size=0.1)

# %%
y_train
# Out:
# 10    1
# 47    0
# 53    1
# 18    0
# 45    1
#      ..
# 20    1
# 83    1
# 6     0
# 27    1
# 22    0
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scalor = StandardScaler()

# %%
X_train = scalor.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.02609968, -1.91228919],
#        [-0.72209109,  0.95944544],
#        [ 1.97487562,  1.13273977],
#        [-1.7660782 , -0.55069088],
#        [-0.02609968, -1.3924062 ],
#        [-0.72209109,  0.24151178],
#        [-0.89608894, -1.4666752 ],
#        [-0.98308786,  0.71188211],
#        [-1.07008679,  1.00895811],
#        [ 1.80087777,  1.08322711],
#        [ 0.84388958,  1.9001861 ],
#        [ 0.06089925,  0.83566378],
#        [ 0.75689066,  0.41480611],
#        [-1.41808249, -1.98655819],
#        [-1.15708572, -0.03080788],
#        [ 1.71387884, -1.07057387],
#        [-0.89608894, -0.77349787],
#        [ 2.14887347, -0.05556421],
#        [ 0.2348971 ,  0.11773012],
#        [ 0.06089925, -1.41716253],
#        [-0.72209109, -0.30312754],
#        [ 0.75689066, -0.64971621],
#        [ 0.93088851, -1.83802019],
#        [-0.98308786,  0.29102445],
#        [ 1.19188529,  0.24151178],
#        [-1.7660782 , -1.1695992 ],
#        [ 1.10488636, -0.89727954],
#        [-0.20009753,  0.48907511],
#        [ 0.14789817, -0.22885855],
#        [ 0.06089925,  0.24151178],
#        [-0.54809323,  0.41480611],
#        [-0.80909001,  0.14248645],
#        [ 0.2348971 ,  0.14248645],
#        [-0.28709646,  1.15749611],
#        [ 0.84388958, -1.44191886],
#        [-1.15708572, -0.8725232 ],
#        [ 0.2348971 , -0.47642188],
#        [ 0.06089925, -0.47642188],
#        [-0.20009753,  1.08322711],
#        [ 1.53988099, -0.20410221],
#        [-0.98308786,  1.8259171 ],
#        [-0.72209109, -0.79825421],
#        [-0.89608894, -0.10507688],
#        [-0.98308786,  0.81090744],
#        [ 0.32189603, -0.15458955],
#        [-0.02609968, -0.50117821],
#        [ 0.75689066,  0.39004978],
#        [ 0.66989173,  0.46431878],
#        [ 0.40889495, -2.11033986],
#        [ 0.66989173, -0.25361488],
#        [ 1.10488636, -0.15458955],
#        [ 1.36588314,  0.14248645],
#        [ 0.66989173,  0.01870478],
#        [-1.85307712, -0.32788388],
#        [ 0.5828928 ,  1.47932843],
#        [ 1.80087777,  0.66236944],
#        [ 1.10488636,  0.36529345],
#        [-1.41808249,  0.66236944],
#        [-0.1130986 , -0.40215288],
#        [ 0.66989173, -0.79825421],
#        [ 0.06089925, -1.0210612 ],
#        [ 0.40889495,  0.93468911],
#        [ 0.84388958,  1.3060341 ],
#        [ 0.84388958,  0.41480611],
#        [-0.98308786, -1.51618786],
#        [-0.63509216, -0.03080788],
#        [ 0.32189603,  0.46431878],
#        [-0.28709646,  0.24151178],
#        [ 1.10488636, -1.78850753],
#        [-2.37507068,  1.50408477],
#        [-2.20107283,  2.74190142],
#        [ 1.27888421, -1.51618786],
#        [-0.80909001, -1.3924062 ],
#        [ 1.27888421,  0.88517644],
#        [-0.63509216, -0.20410221],
#        [ 0.5828928 ,  0.78615111],
#        [-0.80909001,  1.33079044],
#        [-1.24408464,  0.58810045],
#        [ 0.93088851,  0.71188211],
#        [-1.07008679, -0.25361488],
#        [-1.15708572, -1.73899486],
#        [ 0.40889495, -0.79825421],
#        [-0.72209109,  2.51909442],
#        [ 0.49589388,  0.39004978],
#        [ 0.40889495,  0.19199912],
#        [ 0.49589388, -0.05556421],
#        [ 1.27888421,  0.19199912],
#        [-0.28709646,  0.51383145],
#        [-0.02609968,  0.04346112],
#        [-0.98308786, -0.05556421]])

# %%
X_test = scalor.transform(X_test)

# %%
X_test
# Out:
# array([[-1.50508142,  1.92494243],
#        [ 1.36588314, -0.82301054],
#        [-0.02609968,  0.66236944],
#        [-0.54809323, -0.37739654],
#        [-0.54809323, -0.20410221],
#        [ 0.84388958, -0.25361488],
#        [-1.07008679,  0.46431878],
#        [-0.54809323,  0.31578078],
#        [-0.28709646,  0.43956245],
#        [-1.07008679,  1.15749611]])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
#model trannig
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict = clf.predict(X_test)

# %%
Y_test
# Out:
# 95    0
# 42    1
# 33    0
# 81    0
# 41    0
# 29    1
# 51    0
# 49    0
# 36    0
# 75    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,y_predict)
# Out:
# 0.9

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (1.17.0)
# Requirement already satisfied: numpy>=2.3.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (2.4.2)
# Requirement already satisfied: pandas>=2.3.3 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Tech Lab 1\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Tech Lab 1\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl',"wb"))
