# %% [markdown]
# # Simple Supervised machine learning

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
data = {
    'CGPA': [8.5, 6.2, 7.8, 5.9, 9.0],
    'iq':[111,60,90,55,99],
    'Placement': [1, 0, 1, 0, 1]  # YES=1, NO=0
}

df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#            CGPA          iq  Placement
# count  5.000000    5.000000   5.000000
# mean   7.480000   83.000000   0.600000
# std    1.377316   24.505102   0.547723
# min    5.900000   55.000000   0.000000
# 25%    6.200000   60.000000   0.000000
# 50%    7.800000   90.000000   1.000000
# 75%    8.500000   99.000000   1.000000
# max    9.000000  111.000000   1.000000

# %%
X = df[['CGPA','iq']]   # Feature
y = df['Placement']  # Label

# %%
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression()

# %%
cgpa = [[9.5,40]]
prediction = model.predict(cgpa)

print("Placed" if prediction[0] == 1 else "Not Placed")
# Out:
# Not Placed
# c:\Users\Shoolini\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("warcoder/infant-cry-audio-corpus")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("warcoder/infant-cry-audio-corpus")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
pip install kagglehub
# Out:
# ...
#
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 2/2 [kagglehub]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("warcoder/infant-cry-audio-corpus")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 39.0M/39.0M [00:04<00:00, 8.68MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Shoolini\.cache\kagglehub\datasets\warcoder\infant-cry-audio-corpus\versions\1
