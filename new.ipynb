# %%
pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    --------------------------------- ------ 1.3/1.6 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 8.2 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
# ...

# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Tech Lab
# [nltk_data]     1\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\Tech Lab
# [nltk_data]     1\AppData\Roaming\nltk_data...
# True

# %%
stop_words = set(stopwords.words("english")) # unique stopwords
lemmatizer = WordNetLemmatizer()

# %%
text = "i love this moveie!!!!"
print(f"Orginal Text: {text}")
# Out:
# Orginal Text: i love this moveie!!!!

# %%
def preprocessing_text(text):
    #1. lower case
    text = text.lower()
    # remove the punctuations
    text = text.translate(str.maketrans(" ", "", string.punctuation))

    # remove special Char
    text = re.sub(r" [^\w\s]","", text)    # match only one char match white spaces , spaces , emojis 


    # token
    token = text.split()


    # Stop word removel
    token = [word for word in token if word not in stop_words]   # ranges

# 6 lemmatization
tokens = [lemmatizer.lemmatize(word) for word in tokens]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 19
#      16     tokens = [word for word in token if word not in stop_words]   # ranges
#      18 # 6 lemmatization
# ---> 19 tokens = [lemmatizer.lemmatize(word) for word in tokens]
#
# NameError: name 'tokens' is not defined

# %%
procesed = procesed(text)
print(f"Processed Text : {procesed}")
